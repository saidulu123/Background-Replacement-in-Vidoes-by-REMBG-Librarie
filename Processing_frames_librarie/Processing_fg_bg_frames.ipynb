# %%
import os
import torch
from PIL import Image
from io import BytesIO
from rembg.bg import remove
from multiprocessing import Pool, cpu_count
import concurrent.futures
import threading
import time

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("using", device, "device")
# Out:
# using cuda device

# %%
# !pip install -U pillow

# %%
# !pip install rembg

# %%
print_lock = threading.Lock()

# %%
def remove_background(input_data):
    try:
        return remove(input_data, alpha_matting=True)
    except Exception as e:
        with print_lock:
            print(f"Error during background removal: {e}")
        return None

# %%
def process_image(input_path, output_folder, background_img_path):
    try:
        # Load the image
        img = Image.open(input_path)
        original_filename = os.path.basename(input_path)
        
        # Save the original image
        original_output_path = os.path.join(output_folder, 'original', original_filename)
        img.save(original_output_path, format='JPEG')
        
        # Remove the background
        with open(input_path, 'rb') as f:
            input_data = f.read()
        
        subject = remove_background(input_data)
        if subject is None:
            return
        
        # Save the masked image to a BytesIO object
        masked_img = Image.open(BytesIO(subject)).convert("RGBA")
        
        # Save the masked image
        masked_output_path = os.path.join(output_folder, 'masked', original_filename)
        masked_img.save(masked_output_path, format='PNG')
        
        # Load background image
        background_img = Image.open(background_img_path).convert("RGBA")
        
        # Resize background to match the foreground
        background_img = background_img.resize(masked_img.size)
        
        # Composite the foreground on the background
        final_img = Image.alpha_composite(background_img, masked_img)
        final_img = final_img.convert("RGB")  # Convert back to RGB mode
        
        # Save the final image
        processed_output_path = os.path.join(output_folder, 'processed', original_filename)
        final_img.save(processed_output_path, format='JPEG')
        
        with print_lock:
            print(f"Processed {original_filename} with background {os.path.basename(background_img_path)}")

    except Exception as e:
        with print_lock:
            print(f"Error processing {input_path} with {background_img_path}: {e}")

# %%
def process_pair(input_folder, output_folder, background_folder, fg_filename, bg_filename):
    fg_path = os.path.join(input_folder, fg_filename)
    bg_path = os.path.join(background_folder, bg_filename)
    process_image(fg_path, output_folder, bg_path)

# %%
def process_folder(input_folder, output_folder, background_folder):
    os.makedirs(os.path.join(output_folder, 'original'), exist_ok=True)
    os.makedirs(os.path.join(output_folder, 'masked'), exist_ok=True)
    os.makedirs(os.path.join(output_folder, 'processed'), exist_ok=True)
    
    fg_files = sorted([f for f in os.listdir(input_folder) if f.endswith(".jpeg") or f.endswith(".jpg")])
    bg_files = sorted([f for f in os.listdir(background_folder) if f.endswith(".jpeg") or f.endswith(".jpg")])
    
    # Ensure equal number of frames
    if len(fg_files) != len(bg_files):
        raise ValueError("The number of foreground and background frames must be the same.")
    
    # Prepare arguments for multiprocessing
    args = [(input_folder, output_folder, background_folder, fg_files[i], bg_files[i]) for i in range(len(fg_files))]
    
    # Use threading for I/O operations
    with concurrent.futures.ThreadPoolExecutor(max_workers=cpu_count()) as executor:
        executor.map(lambda p: process_pair(*p), args)

# %%
input_folder = r"E:\My projects\Rembg\frames_extraction_HD\fg_frames"
output_folder = r"E:\My projects\Rembg\output_frames_rembg"
background_folder = r'E:\My projects\Rembg\frames_extraction_HD\bg_frames'

# %%
start_time = time.time()
process_folder(input_folder, output_folder, background_folder)
end_time = time.time()
# Out:
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0180.jpg with background frame_0180.jpg
# Processed frame_0176.jpg with background frame_0176.jpg
# Processed frame_0175.jpg with background frame_0175.jpg
# Processed frame_0178.jpg with background frame_0178.jpg
# Processed frame_0177.jpg with background frame_0177.jpg
# Processed frame_0182.jpg with background frame_0182.jpg
# Processed frame_0184.jpg with background frame_0184.jpg
# Processed frame_0179.jpg with background frame_0179.jpg
# Processed frame_0190.jpg with background frame_0190.jpg
# Processed frame_0189.jpg with background frame_0189.jpg
# Processed frame_0187.jpg with background frame_0187.jpg
# Processed frame_0186.jpg with background frame_0186.jpg
# Processed frame_0191.jpg with background frame_0191.jpg
# Processed frame_0188.jpg with background frame_0188.jpg
# Processed frame_0181.jpg with background frame_0181.jpg
# Processed frame_0185.jpg with background frame_0185.jpg
# Processed frame_0183.jpg with background frame_0183.jpg
# Processed frame_0193.jpg with background frame_0193.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0192.jpg with background frame_0192.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0195.jpg with background frame_0195.jpg
# Processed frame_0201.jpg with background frame_0201.jpg
# Processed frame_0194.jpg with background frame_0194.jpg
# Processed frame_0199.jpg with background frame_0199.jpg
# Processed frame_0198.jpg with background frame_0198.jpg
# Processed frame_0197.jpg with background frame_0197.jpg
# Processed frame_0196.jpg with background frame_0196.jpg
# Processed frame_0200.jpg with background frame_0200.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0202.jpg with background frame_0202.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0203.jpg with background frame_0203.jpg
# Processed frame_0228.jpg with background frame_0228.jpg
# Processed frame_0229.jpg with background frame_0229.jpg
# Processed frame_0230.jpg with background frame_0230.jpg
# Processed frame_0225.jpg with background frame_0225.jpg
# Processed frame_0207.jpg with background frame_0207.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0227.jpg with background frame_0227.jpg
# Processed frame_0208.jpg with background frame_0208.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0213.jpg with background frame_0213.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0217.jpg with background frame_0217.jpg
# Processed frame_0204.jpg with background frame_0204.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0222.jpg with background frame_0222.jpg
# Processed frame_0214.jpg with background frame_0214.jpg
# Processed frame_0211.jpg with background frame_0211.jpg
# Processed frame_0223.jpg with background frame_0223.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0212.jpg with background frame_0212.jpg
# Processed frame_0231.jpg with background frame_0231.jpg
# Processed frame_0206.jpg with background frame_0206.jpg
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0234.jpg with background frame_0234.jpg
# Processed frame_0218.jpg with background frame_0218.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0221.jpg with background frame_0221.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0215.jpg with background frame_0215.jpg
# Processed frame_0220.jpg with background frame_0220.jpg
# Processed frame_0219.jpg with background frame_0219.jpg
# Processed frame_0216.jpg with background frame_0216.jpg
# Processed frame_0245.jpg with background frame_0245.jpg
# Processed frame_0209.jpg with background frame_0209.jpg
# Processed frame_0247.jpg with background frame_0247.jpg
# Processed frame_0248.jpg with background frame_0248.jpg
# Processed frame_0205.jpg with background frame_0205.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0237.jpg with background frame_0237.jpg
# Processed frame_0210.jpg with background frame_0210.jpg
# Processed frame_0246.jpg with background frame_0246.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0224.jpg with background frame_0224.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0244.jpg with background frame_0244.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0252.jpg with background frame_0252.jpg
# Processed frame_0251.jpg with background frame_0251.jpg
# Processed frame_0226.jpg with background frame_0226.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0232.jpg with background frame_0232.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0254.jpg with background frame_0254.jpg
# Processed frame_0253.jpg with background frame_0253.jpg
# Processed frame_0255.jpg with background frame_0255.jpg
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0250.jpg with background frame_0250.jpg
# Processed frame_0243.jpg with background frame_0243.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-03
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
# ...
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0633.jpg with background frame_0633.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0641.jpg with background frame_0641.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0642.jpg with background frame_0642.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0643.jpg with background frame_0643.jpg
# Processed frame_0662.jpg with background frame_0662.jpg
# Processed frame_0645.jpg with background frame_0645.jpg
# Processed frame_0661.jpg with background frame_0661.jpg
# Processed frame_0657.jpg with background frame_0657.jpg
# Processed frame_0667.jpg with background frame_0667.jpg
# Processed frame_0663.jpg with background frame_0663.jpg
# Processed frame_0668.jpg with background frame_0668.jpg
# Processed frame_0659.jpg with background frame_0659.jpg
# Processed frame_0655.jpg with background frame_0655.jpg
# Processed frame_0651.jpg with background frame_0651.jpg
# Processed frame_0654.jpg with background frame_0654.jpg
# Processed frame_0653.jpg with background frame_0653.jpg
# Processed frame_0669.jpg with background frame_0669.jpg
# Processed frame_0660.jpg with background frame_0660.jpg
# Processed frame_0658.jpg with background frame_0658.jpg
# Processed frame_0644.jpg with background frame_0644.jpg
# Processed frame_0650.jpg with background frame_0650.jpg
# Processed frame_0664.jpg with background frame_0664.jpg
# Processed frame_0666.jpg with background frame_0666.jpg
# Processed frame_0670.jpg with background frame_0670.jpg
# Processed frame_0649.jpg with background frame_0649.jpg
# Processed frame_0652.jpg with background frame_0652.jpg
# Processed frame_0671.jpg with background frame_0671.jpg
# Processed frame_0672.jpg with background frame_0672.jpg
# Processed frame_0656.jpg with background frame_0656.jpg
# Processed frame_0648.jpg with background frame_0648.jpg
# Processed frame_0647.jpg with background frame_0647.jpg
# Processed frame_0646.jpg with background frame_0646.jpg
# Processed frame_0665.jpg with background frame_0665.jpg
# Processed frame_0674.jpg with background frame_0674.jpg
# Processed frame_0673.jpg with background frame_0673.jpg
# Processed frame_0675.jpg with background frame_0675.jpg
# Processed frame_0676.jpg with background frame_0676.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0680.jpg with background frame_0680.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0677.jpg with background frame_0677.jpg
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0681.jpg with background frame_0681.jpg
# Processed frame_0682.jpg with background frame_0682.jpg
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0679.jpg with background frame_0679.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0683.jpg with background frame_0683.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0684.jpg with background frame_0684.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0699.jpg with background frame_0699.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0700.jpg with background frame_0700.jpg
# Processed frame_0678.jpg with background frame_0678.jpg
# Processed frame_0706.jpg with background frame_0706.jpg
# PERFORMANCE WARNING:PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
#
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0698.jpg with background frame_0698.jpg
# Processed frame_0322.jpg with background frame_0322.jpg
# Processed frame_0705.jpg with background frame_0705.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0686.jpg with background frame_0686.jpg
# Processed frame_0701.jpg with background frame_0701.jpg
# Processed frame_0688.jpg with background frame_0688.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0703.jpg with background frame_0703.jpg
# Processed frame_0702.jpg with background frame_0702.jpg
# Processed frame_0694.jpg with background frame_0694.jpg
# Processed frame_0689.jpg with background frame_0689.jpg
# Processed frame_0695.jpg with background frame_0695.jpg
# Processed frame_0687.jpg with background frame_0687.jpg
# Processed frame_0696.jpg with background frame_0696.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0690.jpg with background frame_0690.jpg
# Processed frame_0697.jpg with background frame_0697.jpg
# Processed frame_0708.jpg with background frame_0708.jpg
# Processed frame_0707.jpg with background frame_0707.jpg
# Processed frame_0685.jpg with background frame_0685.jpg
# Processed frame_0704.jpg with background frame_0704.jpg
# Processed frame_0693.jpg with background frame_0693.jpg
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# Processed frame_0323.jpg with background frame_0323.jpg
# Processed frame_0713.jpg with background frame_0713.jpg
# Processed frame_0716.jpg with background frame_0716.jpg
# Processed frame_0715.jpg with background frame_0715.jpg
# Processed frame_0714.jpg with background frame_0714.jpg
# Processed frame_0691.jpg with background frame_0691.jpg
# Processed frame_0718.jpg with background frame_0718.jpg
# Processed frame_0717.jpg with background frame_0717.jpg
# Processed frame_0719.jpg with background frame_0719.jpg
# Processed frame_0712.jpg with background frame_0712.jpg
# Processed frame_0692.jpg with background frame_0692.jpg
# Processed frame_0720.jpg with background frame_0720.jpg
# Processed frame_0710.jpg with background frame_0710.jpg
# Processed frame_0721.jpg with background frame_0721.jpg
# Processed frame_0711.jpg with background frame_0711.jpg
# Processed frame_0709.jpg with background frame_0709.jpg

# %%
print(f"Processing completed in {end_time - start_time} seconds")
# Out:
# Processing completed in 608.9995839595795 seconds
